# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Affairs.csv')
data
# Out:
#      Unnamed: 0  affairs  gender   age  yearsmarried children  religiousness  \
# 0             4        0    male  37.0         10.00       no              3
# 1             5        0  female  27.0          4.00       no              4
# 2            11        0  female  32.0         15.00      yes              1
# 3            16        0    male  57.0         15.00      yes              5
# 4            23        0    male  22.0          0.75       no              2
# ..          ...      ...     ...   ...           ...      ...            ...
# 596        1938        1    male  22.0          1.50      yes              1
# 597        1941        7  female  32.0         10.00      yes              2
# 598        1954        2    male  32.0         10.00      yes              2
# 599        1959        2    male  22.0          7.00      yes              3
# 600        9010        1  female  32.0         15.00      yes              3
#
#      education  occupation  rating
# ...

# %%
data.affairs.describe()
# Out:
# count    601.000000
# mean       1.455907
# std        3.298758
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       12.000000
# Name: affairs, dtype: float64

# %%
data.age.describe()
# Out:
# count    601.000000
# mean      32.487521
# std        9.288762
# min       17.500000
# 25%       27.000000
# 50%       32.000000
# 75%       37.000000
# max       57.000000
# Name: age, dtype: float64

# %%
del data["Unnamed: 0"]
data
# Out:
#      affairs  gender   age  yearsmarried children  religiousness  education  \
# 0          0    male  37.0         10.00       no              3         18
# 1          0  female  27.0          4.00       no              4         14
# 2          0  female  32.0         15.00      yes              1         12
# 3          0    male  57.0         15.00      yes              5         18
# 4          0    male  22.0          0.75       no              2         17
# ..       ...     ...   ...           ...      ...            ...        ...
# 596        1    male  22.0          1.50      yes              1         12
# 597        7  female  32.0         10.00      yes              2         18
# 598        2    male  32.0         10.00      yes              2         17
# 599        2    male  22.0          7.00      yes              3         18
# 600        1  female  32.0         15.00      yes              3         14
#
#      occupation  rating
# 0             7       4
# ...

# %%
data.groupby(by=["affairs"])["gender"].count()
# Out:
# affairs
# 0     451
# 1      34
# 2      17
# 3      19
# 7      42
# 12     38
# Name: gender, dtype: int64

# %%
df = data.groupby(by = ["affairs","gender"])["age"].agg(['mean'])
df
# Out:
#                      mean
# affairs gender
# 0       female  30.296296
#         male    34.382212
# 1       female  29.700000
#         male    30.684211
# 2       female  32.714286
#         male    36.000000
# 3       female  35.125000
#         male    30.636364
# 7       female  32.909091
#         male    35.750000
# 12      female  33.050000
#         male    37.555556

# %%
data
# Out:
#      affairs  gender   age  yearsmarried children  religiousness  education  \
# 0          0    male  37.0         10.00       no              3         18
# 1          0  female  27.0          4.00       no              4         14
# 2          0  female  32.0         15.00      yes              1         12
# 3          0    male  57.0         15.00      yes              5         18
# 4          0    male  22.0          0.75       no              2         17
# ..       ...     ...   ...           ...      ...            ...        ...
# 596        1    male  22.0          1.50      yes              1         12
# 597        7  female  32.0         10.00      yes              2         18
# 598        2    male  32.0         10.00      yes              2         17
# 599        2    male  22.0          7.00      yes              3         18
# 600        1  female  32.0         15.00      yes              3         14
#
#      occupation  rating
# 0             7       4
# ...

# %%
ex = open('Affairs.csv')
exr = csv.reader(ex)
pdata = list(exr)
print(pdata)
# Out:
# [['', 'affairs', 'gender', 'age', 'yearsmarried', 'children', 'religiousness', 'education', 'occupation', 'rating'], ['4', '0', 'male', '37', '10', 'no', '3', '18', '7', '4'], ['5', '0', 'female', '27', '4', 'no', '4', '14', '6', '4'], ['11', '0', 'female', '32', '15', 'yes', '1', '12', '1', '4'], ['16', '0', 'male', '57', '15', 'yes', '5', '18', '6', '5'], ['23', '0', 'male', '22', '0.75', 'no', '2', '17', '6', '3'], ['29', '0', 'female', '32', '1.5', 'no', '2', '17', '5', '5'], ['44', '0', 'female', '22', '0.75', 'no', '2', '12', '1', '3'], ['45', '0', 'male', '57', '15', 'yes', '2', '14', '4', '4'], ['47', '0', 'female', '32', '15', 'yes', '4', '16', '1', '2'], ['49', '0', 'male', '22', '1.5', 'no', '4', '14', '4', '5'], ['50', '0', 'male', '37', '15', 'yes', '2', '20', '7', '2'], ['55', '0', 'male', '27', '4', 'yes', '4', '18', '6', '4'], ['64', '0', 'male', '47', '15', 'yes', '5', '17', '6', '4'], ['80', '0', 'female', '22', '1.5', 'no', '2', '17', '5', '4'], ['86', '0', 'female
# ...

# %%
pdata[1][:]
# Out:
# ['4', '0', 'male', '37', '10', 'no', '3', '18', '7', '4']

# %%
x = list()
y = list()
for i in range(1,601):
    x.append(pdata[i][3])
    y.append(pdata[i][1])

plt.scatter(x,y)
plt.show()

# %%
fig = sns.scatterplot('age','affairs',data=data,hue='gender',palette='Set1'
                      ,s = 100,alpha=0.22)
plt.xlabel('age')
# plt.ylabel('affairs')
# plt.savefig('ag.png')
# Out:
# f:\python3.9.2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0, 'age')

# %%
df_corr = data.corr()
sns.heatmap(df_corr,cmap='Blues',annot = True,
            xticklabels=df_corr.columns.values,yticklabels=df_corr.columns.values)
plt.xticks(fontsize =15)
plt.yticks(fontsize =15)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  [Text(0, 0.5, 'affairs'),
#   Text(0, 1.5, 'age'),
#   Text(0, 2.5, 'yearsmarried'),
#   Text(0, 3.5, 'religiousness'),
#   Text(0, 4.5, 'education'),
#   Text(0, 5.5, 'occupation'),
#   Text(0, 6.5, 'rating')])
