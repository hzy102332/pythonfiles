# %%
import turtle, time, math

windows = turtle.Screen()
windows.title("campus overview")
windows.setup(900, 600)
windows.tracer(0)#speed up drawing
turtle.speed(3)
turtle.hideturtle()

rec=turtle.Turtle()
rec.speed(0)
rec.shape("square") 
rec.color("white") 
rec.penup() 
rec.goto(210,-90)
rec.shapesize( stretch_wid = 1.5, stretch_len = 3.5)

tri=turtle.Turtle() 
tri.speed(0) 
tri.shape("triangle") 
tri.color("white") 
tri.penup() 
tri.goto(170,-90)
tri.shapesize( stretch_wid = 3, stretch_len = -2)

xy = [[210,-90],[120,-140],[180,-190]]#store the coordinates of rectangle
xy2 = [[170,-90],[80,-140],[140,-190]]#store the coordinates of triangle
index = 0
index2 = 0

def move_rec():
    global index
    if index == 3:
        index = 0
    rec.setx(xy[index][0])
    rec.sety(xy[index][1])
    index += 1
    time.sleep(0.5)
        
def move_tri():
    global index2
    if index2 == 3:
        index2 = 0
    tri.setx(xy2[index2][0])
    tri.sety(xy2[index2][1])
    index2 += 1
    time.sleep(0.5)
    
def arc(t_obj,r,angle):
    arc_length = 2*math.pi*r*(angle/366.0)
    n = int(arc_length/3)+1
    length_each_step = arc_length/n
    angle_each_step = float(angle)/n

    for i in range(n):
        t_obj.fd(length_each_step)
        t_obj.lt(angle_each_step)
        
def show(name):
    
    time.sleep(2)
    turtle.clear()
    turtle.bgpic(name)
    turtle.goto(0,250)
    turtle.color('black')
    turtle.write('Press Esc to return select page!',align="center",font=("Courier", 14, "bold"))
    
def one():
    windows.tracer(1)
    rec.hideturtle()
    tri.hideturtle()
    turtle.speed(2)
    turtle.clear()
    turtle.bgpic('')

    #草地
    turtle.penup()
    turtle.goto(-150,-220)
    turtle.pendown()
    turtle.begin_fill()
    turtle.color('yellowgreen')
    turtle.goto(450,-200)
    turtle.goto(450,-220)
    turtle.goto(-150,-220)
    turtle.end_fill()
    #柏油地
    turtle.begin_fill()
    turtle.color('gray9')
    turtle.goto(-450,-230)
    turtle.goto(-450,-300)
    turtle.goto(450,-300)
    turtle.goto(450,-220)
    turtle.goto(-150,-220)
    turtle.end_fill()
    turtle.penup()

    #mountain
    turtle.goto(-450,-10)
    turtle.pendown()
    turtle.begin_fill()
    turtle.color('palegreen1')
    turtle.goto(-300,20)
    turtle.goto(-150,-10)
    turtle.goto(-450,-60)
    turtle.goto(-450,-10)
    turtle.end_fill()
    turtle.penup()

    turtle.goto(-450,-60)
    turtle.pendown()
    turtle.begin_fill()
    turtle.color('palegreen4')
    turtle.goto(-150,-10)
    turtle.goto(-60,20)
    turtle.goto(450,-60)
    turtle.goto(450,-195)
    turtle.goto(-450,-200)
    turtle.goto(-450,-60)
    turtle.end_fill()
    turtle.penup()

    # building
    turtle.speed(1)
    turtle.goto(-450,-220)
    turtle.pendown()
    turtle.begin_fill()
    turtle.color('bisque')
    turtle.goto(-450,-130)
    turtle.goto(-400,-130)
    turtle.goto(-400,-140)
    turtle.goto(-425,-140)
    turtle.goto(-425,-150)
    turtle.goto(-410,-150)
    turtle.goto(-410,-170)
    turtle.goto(-390,-170)
    turtle.goto(-390,-110)
    turtle.goto(-280,-95)
    turtle.goto(-280,-70)
    turtle.goto(-250,-65)
    turtle.goto(-225,-70)
    turtle.goto(-225,-150)
    turtle.goto(-200,-150)
    turtle.goto(-200,-130)
    turtle.goto(-100,-125)
    turtle.goto(-100,-100)
    turtle.goto(-60,-95)
    turtle.goto(35,-105)
    turtle.goto(195,-85)
    turtle.goto(195,-70)
    turtle.goto(220,-68)
    turtle.goto(250,-75)
    turtle.goto(250,-85)
    turtle.goto(315,-95)
    turtle.goto(355,-95)
    turtle.goto(355,-115)
    turtle.goto(380,-117)
    turtle.goto(380,-110)
    turtle.goto(420,-105)
    turtle.goto(425,-180)
    turtle.goto(450,-180)
    turtle.goto(450,-195)
    turtle.goto(-450,-220)
    turtle.end_fill()    
    turtle.penup()
    
    show('GEH.png')

    
def two():
    windows.tracer(1)
    global check
    check = False
    rec.hideturtle()
    tri.hideturtle()
    
    turtle.speed(1)
    turtle.clear()
    turtle.bgpic('')
    #outline
    turtle.penup()
    turtle.pensize(5)
    turtle.goto(-420,-135)
    turtle.pendown()
    turtle.goto(-420,-50)
    turtle.goto(-370,-50)
    turtle.goto(-370,30)
    turtle.goto(-415,35)
    turtle.goto(-415,108)
    turtle.goto(-370,108)
    turtle.goto(-370,180)
    turtle.goto(350,205)
    turtle.goto(350,185)
    turtle.goto(410,185)
    turtle.goto(412,150)
    turtle.goto(350,130)
    turtle.goto(350,75)
    turtle.goto(415,75)
    turtle.goto(415,-5)
    turtle.goto(260,-25)
    turtle.goto(260,-10)
    turtle.goto(260,-45)
    turtle.goto(320,-45)
    turtle.goto(440,-120)
    turtle.goto(260,-130)
    turtle.goto(250,-125)
    turtle.goto(-50,-125)
    turtle.goto(-60,-130)
    turtle.goto(-420,-135)
    turtle.penup()
    #inner
    turtle.goto(350,130)
    turtle.pendown()
    turtle.goto(350,140)
    turtle.goto(210,140)
    turtle.penup()
    turtle.goto(-370,108)
    turtle.pendown()
    turtle.goto(60,115)
    turtle.goto(250,185)
    turtle.goto(350,185)
    turtle.penup()
    turtle.goto(412,150)
    turtle.pendown()
    turtle.goto(240,150)
    turtle.goto(70,90)
    turtle.goto(-260,90)
    turtle.goto(-260,60)
    turtle.goto(350,75)
    turtle.penup()
    turtle.goto(-415,35)
    turtle.pendown()
    turtle.goto(415,50)
    turtle.goto(415,20)
    turtle.goto(350,18)
    turtle.goto(350,45)
    turtle.goto(350,18)
    turtle.goto(55,12)
    turtle.goto(50,15)
    turtle.goto(-210,10)
    turtle.goto(-210,-50)
    turtle.goto(-370,-50)
    turtle.goto(260,-45)
    turtle.goto(-200,-50)
    turtle.goto(-200,-15)
    turtle.goto(415,-5)
    turtle.penup()
    turtle.goto(-60,-130)
    turtle.pendown()
    turtle.goto(-60,-70)
    turtle.goto(-50,-70)
    turtle.goto(-50,-120)
    turtle.goto(-50,-70)
    turtle.goto(250,-70)
    turtle.goto(250,-120)
    turtle.goto(260,-130)
    turtle.goto(260,-70)
    turtle.goto(250,-70)
    turtle.penup()
    turtle.goto(305,-45)
    turtle.pendown()
    turtle.goto(300,-128)
    turtle.goto(340,-125)
    turtle.goto(340,-120)
    turtle.pensize(10)
    turtle.goto(340,-10)
    turtle.penup()
    turtle.goto(300,-25)
    turtle.pendown()
    turtle.goto(300,-40)
    #rectangle
    turtle.speed(0)
    turtle.pensize(5)
    for i in range(0,13):
        turtle.penup()
        turtle.goto(-360+i*22,-115)
        turtle.pendown()
        turtle.seth(0)
        for x in range(0, 5):
            if x % 2 == 1:
                n = 40
            else:
                n = 10
            turtle.forward(n)
            turtle.left(90)
    #door
    for i in range(0,8):
        turtle.penup()
        turtle.goto(-50+i*10,-125)
        turtle.pendown()
        turtle.seth(0)
        for x in range(0, 5):
            if x % 2 == 1:
                n = 35
            else:
                n = 10
            turtle.forward(n)
            turtle.left(90)

    for i in range(0,4):
        turtle.penup()
        turtle.goto(-50+i*20,-90)
        turtle.pendown()
        turtle.seth(0)
        for x in range(0, 5):
            if x % 2 == 1:
                n = 20
            else:
                n = 20
            turtle.forward(n)
            turtle.left(90)

    for i in range(0,10):
        turtle.penup()
        turtle.goto(40+i*20,-125)
        turtle.pendown()
        turtle.seth(0)
        for x in range(0, 5):
            if x % 2 == 1:
                n = 35
            else:
                n = 20
            turtle.forward(n)
            turtle.left(90)
    for i in range(0,10):
        turtle.penup()
        turtle.goto(40+i*20,-90)
        turtle.pendown()
        turtle.seth(0)
        for x in range(0, 5):
            if x % 2 == 1:
                n = 20
            else:
                n = 20
            turtle.forward(n)
            turtle.left(90)
    turtle.penup()

    #letter
    turtle.goto(-332,60)
    turtle.color('grey')
    turtle.write('CBPM',align="center",font=("Arial",18,"bold"))
    turtle.goto(-250,120)
    turtle.write('U N I V E R S I T Y',align="center",font=("Arial",15,"normal"))
    turtle.goto(-230,140)
    turtle.write('W E N Z H O U - K E A N ',align="center",font=("Arial",15,"normal"))
    turtle.penup()
    
    show('CBPM.png')
    
def three():
    windows.tracer(1)
    rec.hideturtle()
    tri.hideturtle()
    
    turtle.speed(1)
    turtle.clear()
    turtle.bgpic('')
    turtle.pensize(3)
    #groud
    turtle.penup()
    turtle.goto(-450,-100)
    turtle.pendown()
    turtle.goto(-390,-100)
    turtle.goto(-280,-128)
    turtle.goto(100,-117)
    turtle.goto(245,-135)
    turtle.goto(390,-120)
    turtle.goto(450,-125)
    # outline
    turtle.penup()
    turtle.goto(-290,-130)
    turtle.pendown()
    turtle.goto(-285,35)
    turtle.goto(65,23)
    turtle.goto(100,-85)
    turtle.goto(65,23)
    turtle.goto(240,45)
    turtle.goto(240,-90)
    turtle.goto(240,45)
    turtle.goto(360,30)
    turtle.goto(365,-120)

    turtle.penup()
    turtle.goto(-250,-125)
    turtle.pendown()

    turtle.goto(-150,-85)
    turtle.pensize(7)
    turtle.goto(-150,-123)
    turtle.pensize(3)
    turtle.goto(-150,-85)

    turtle.goto(-95,-85)
    turtle.pensize(7)
    turtle.goto(-95,-122)
    turtle.pensize(3)
    turtle.goto(-98,-85)

    turtle.goto(5,-85)
    turtle.pensize(9)
    turtle.goto(5,-118)
    turtle.pensize(3)
    turtle.goto(5,-85)

    turtle.goto(100,-80)

    turtle.goto(105,-83)
    turtle.pensize(9)
    turtle.goto(105,-115)
    turtle.pensize(3)
    turtle.goto(100,-80)

    turtle.goto(150,-85)
    turtle.pensize(9)
    turtle.goto(150,-119)
    turtle.pensize(3)
    turtle.goto(150,-85)

    turtle.goto(240,-90)
    turtle.pensize(7)
    turtle.goto(240,-133)
    turtle.pensize(3)
    turtle.goto(240,-90)
    turtle.seth(0)
    arc(turtle,120,50)
    turtle.right(115)
    arc(turtle,80,38)
    turtle.penup()
    turtle.goto(-210,-125)
    turtle.pendown()
    turtle.goto(-150,-100)
    turtle.goto(100,-90)
    turtle.goto(240,-100)
    turtle.goto(360,-95)

    #1
    turtle.penup()
    turtle.goto(-220,-5)
    turtle.pendown()
    turtle.goto(-150,0)
    turtle.goto(200,0)
    turtle.goto(150,-5)
    turtle.goto(-150,-5)
    turtle.goto(-220,-5)
    #2
    turtle.penup()
    turtle.goto(-200,-20)
    turtle.pendown()
    turtle.goto(-130,-15)
    turtle.goto(220,-15)
    turtle.goto(100,-20)
    turtle.goto(-130,-20)
    turtle.goto(-200,-20)
    #3
    turtle.penup()
    turtle.goto(-180,-35)
    turtle.pendown()
    turtle.goto(-110,-30)
    turtle.goto(210,-30)
    turtle.goto(190,-35)
    turtle.goto(-180,-35)
    #4
    turtle.penup()
    turtle.goto(-150,-50)
    turtle.pendown()
    turtle.goto(-90,-45)
    turtle.goto(150,-45)
    turtle.goto(210,-50)
    turtle.goto(-150,-50)
    #5
    turtle.penup()
    turtle.goto(-160,-65)
    turtle.pendown()
    turtle.goto(-90,-60)
    turtle.goto(170,-60)
    turtle.goto(210,-65)
    turtle.goto(-160,-65)
    turtle.penup()


    show('qiuguan.png')
    
def escape():
    windows.tracer(0)
    global check
    check = True
    turtle.color('black')
    turtle.clear()
    turtle.speed(3)
    turtle.bgpic('gate.png')
    turtle.penup()
    turtle.goto(0,150)
    turtle.write('Welcome to Wenzhou-Kean University', align="center",font=("Courier", 16, "bold"))
    turtle.goto(0,100)
    turtle.write('You can click on the corresponding number to see the building', align="center",font=("Courier", 12))
    turtle.goto(0,-100)
    turtle.write('General Education Hall (1)', align="center",font=("Courier", 13, "bold"))
    turtle.goto(0,-150)
    turtle.write('CBPM (2)', align="center",font=("Courier", 13, "bold"))
    turtle.goto(0,-200)
    turtle.write('Gymnasium Complex (3)', align="center",font=("Courier", 13, "bold"))
    
    rec.showturtle()
    tri.showturtle()
    

    
escape()
check = True
while True:
 
    turtle.onkey(one, "1")
    turtle.onkey(two,"2")
    turtle.onkey(three, "3")
    turtle.onkey(escape, "Escape")
    windows.update()
    if check:
        move_tri()
        move_rec()
    
    turtle.listen()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-221d5db3a686> in <module>
#     516     windows.update()
#     517     if check:
# --> 518         move_tri()
#     519         move_rec()
#     520
#
# <ipython-input-1-221d5db3a686> in move_tri()
#      42     if index2 == 3:
#      43         index2 = 0
# ---> 44     tri.setx(xy2[index2][0])
#      45     tri.sety(xy2[index2][1])
#      46     index2 += 1
#
# F:\python3.9.2\lib\turtle.py in setx(self, x)
#    1807         (10.00, 240.00)
#    1808         """
# -> 1809         self._goto(Vec2D(x, self._position[1]))
#    1810
#    1811     def sety(self, y):
#
# F:\python3.9.2\lib\turtle.py in _goto(self, end)
#    3157                       (self.currentLineItem,
#    3158                       self.currentLine[:],
# -> 3159                       screen._pointlist(self.currentLineItem),
# ...

# %%
import turtle,time

wn = turtle.Screen()
wn.title("Bound Ball Game")
wn.setup( 900 , 600 )
wn.bgcolor("black")
wn.tracer( 0 )

rec=turtle.Turtle()
rec.speed(0)
rec.shape("square") 
rec.color("white") 
rec.penup() 
rec.goto(210,-90)
rec.shapesize( stretch_wid = 1.5, stretch_len = 3.5)

tri=turtle.Turtle() 
tri.speed(0) 
tri.shape("triangle") 
tri.color("white") 
tri.penup() 
tri.goto(170,-90)
tri.shapesize( stretch_wid = 3, stretch_len = -2)

xy = [[210,-90],[120,-140],[180,-190]]
xy2 = [[170,-90],[80,-140],[140,-190]]
index = 0
index2 = 0

def move_rec():
    global index
    if index == 3:
        index = 0
    rec.setx(xy[index][0])
    rec.sety(xy[index][1])
    index += 1
    time.sleep(1)
        
def move_tri():
    global index2
    if index2 == 3:
        index2 = 0
    tri.setx(xy2[index2][0])
    tri.sety(xy2[index2][1])
    index2 += 1
    time.sleep(1)
    
while True:
    
#     tri.hideturtle()
  
    wn.update()
    
    move_tri()
    move_rec()

# %%
import turtle
import math

# turtle.clear()
windows = turtle.Screen()
windows.title("campus overview")
windows.setup(900, 600)
turtle.speed(0)
# turtle.hideturtle()
turtle.pensize(2)

turtle.bgpic('qiuguan.png')
#     turtle.bgpic('')
turtle.goto(0,0)
turtle.pendown()
turtle.begin_fill()
turtle.color('black')
turtle.circle(4)
turtle.end_fill()
turtle.color('white')
turtle.penup()
turtle.goto(-450,200)
turtle.pendown()
turtle.goto(450,200)
turtle.goto(450,150)
turtle.goto(-450,150)
turtle.goto(-450,100)
turtle.goto(450,100)
turtle.goto(450,50)
turtle.goto(-450,50)
turtle.goto(-450,0)
turtle.goto(450,0)
turtle.goto(450,-50)
turtle.goto(-450,-50)
turtle.goto(-450,-100)
turtle.goto(450,-100)
turtle.goto(450,-150)
turtle.goto(-450,-150)
turtle.goto(-450,-200)
turtle.goto(450,-200)
turtle.goto(450,-250)
turtle.goto(-450,-250)
turtle.goto(-450,-300)
turtle.goto(450,-300)

turtle.goto(350,-300)
turtle.goto(350,300)
turtle.goto(250,300)
turtle.goto(250,-300)
turtle.goto(150,-300)
turtle.goto(150,300)
turtle.goto(50,300)
turtle.goto(50,-300)
turtle.goto(-50,-300)
turtle.goto(-50,300)
turtle.goto(-150,300)
turtle.goto(-150,-300)
turtle.goto(-250,-300)
turtle.goto(-250,300)
turtle.goto(-350,300)
turtle.goto(-350,-300)
turtle.goto(-450,-300)
turtle.goto(-450,300)
turtle.color('black')


# #outline
# turtle.pensize(3)
# turtle.penup()
# turtle.goto(-450,-240)
# turtle.pendown()
# turtle.goto(-120,-235)
# turtle.goto(-110,-300)
# turtle.goto(180,-300)
# turtle.goto(155,-230)
# turtle.goto(450,-210)
# turtle.penup()
# turtle.goto(-385,-238)
# turtle.pendown()
# turtle.goto(-385,185)
# turtle.goto(0,190)
# turtle.goto(390,180)
# turtle.goto(390,-210)
# turtle.goto(380,-211)
# turtle.goto(340,-200)
# turtle.goto(350,150)
# turtle.goto(380,165)
# turtle.goto(380,-211)
# turtle.goto(380,165)
# turtle.goto(0,170)
# turtle.goto(-375,165)
# turtle.goto(-375,-238)
# turtle.goto(-345,-220)
# turtle.goto(-350,150)
# turtle.goto(-310,135)
# turtle.goto(-310,-55)
# turtle.goto(-290,-53)
# turtle.goto(-290,130)
# turtle.goto(-310,135)
# turtle.goto(-290,130)
# turtle.goto(-280,120)
# turtle.goto(-280,-50)
# turtle.goto(-280,120)
# turtle.goto(70,125)
# turtle.goto(70,100)
# turtle.goto(-70,100)
# turtle.goto(,)

#groud
turtle.penup()
turtle.goto(-450,-100)
turtle.pendown()
turtle.goto(-390,-100)
turtle.goto(-280,-128)
turtle.goto(100,-117)
turtle.goto(245,-135)
turtle.goto(390,-120)
turtle.goto(450,-125)
# outline
turtle.penup()
turtle.goto(-290,-130)
turtle.pendown()
turtle.goto(-285,35)
turtle.goto(65,23)

turtle.goto(80,-85)
turtle.goto(65,23)
turtle.goto(240,45)
turtle.goto(240,-90)
turtle.goto(240,45)
turtle.goto(360,30)
turtle.goto(365,-120)

turtle.penup()
# turtle.goto(-250,-125)
# turtle.pendown()

# turtle.goto(-150,-85)
# turtle.pensize(7)
# turtle.goto(-150,-123)
# turtle.pensize(3)
# turtle.goto(-150,-85)

# turtle.goto(-95,-85)
# turtle.pensize(7)
# turtle.goto(-95,-122)
# turtle.pensize(3)
# turtle.goto(-98,-85)

# turtle.goto(5,-85)
# turtle.pensize(9)
# turtle.goto(5,-118)
# turtle.pensize(3)
# turtle.goto(5,-85)

# turtle.goto(100,-80)

# turtle.goto(105,-83)
# turtle.pensize(9)
# turtle.goto(105,-115)
# turtle.pensize(3)
# turtle.goto(100,-80)

# turtle.goto(150,-85)
# turtle.pensize(9)
# turtle.goto(150,-119)
# turtle.pensize(3)
# turtle.goto(150,-85)

# turtle.goto(240,-90)
# turtle.pensize(7)
# turtle.goto(240,-133)
# turtle.pensize(3)
# turtle.goto(240,-90)
# turtle.seth(0)
# turtle.penup()
# turtle.goto(-210,-125)
# turtle.pendown()
# turtle.goto(-150,-100)
# turtle.goto(100,-90)
# turtle.goto(240,-100)
# turtle.goto(360,-95)

# #1
# turtle.penup()
# turtle.goto(-220,-5)
# turtle.pendown()
# turtle.goto(-150,0)
# turtle.goto(200,0)
# turtle.goto(150,-5)
# turtle.goto(-150,-5)
# turtle.goto(-220,-5)
# #2
# turtle.penup()
# turtle.goto(-200,-20)
# turtle.pendown()
# turtle.goto(-130,-15)
# turtle.goto(220,-15)
# turtle.goto(100,-20)
# turtle.goto(-130,-20)
# turtle.goto(-200,-20)
# #3
# turtle.penup()
# turtle.goto(-180,-35)
# turtle.pendown()
# turtle.goto(-110,-30)
# turtle.goto(210,-30)
# turtle.goto(190,-35)
# turtle.goto(-180,-35)
# #4
# turtle.penup()
# turtle.goto(-150,-50)
# turtle.pendown()
# turtle.goto(-90,-45)
# turtle.goto(150,-45)
# turtle.goto(210,-50)
# turtle.goto(-150,-50)
# #5
# turtle.penup()
# turtle.goto(-160,-65)
# turtle.pendown()
# turtle.goto(-90,-60)
# turtle.goto(170,-60)
# turtle.goto(210,-65)
# turtle.goto(-160,-65)
# turtle.penup()



turtle.penup()

# %%
import turtle, time, math

windows = turtle.Screen()
windows.title("campus overview")
windows.setup(900, 600)
windows.tracer(0)#speed up drawing
turtle.speed(3)
turtle.hideturtle()

def escape():
    windows.tracer(0)
    global check
    check = True
    turtle.color('black')
    turtle.clear()
    turtle.speed(3)
    turtle.bgpic('gate.png')
    turtle.penup()
    turtle.goto(0,150)
    turtle.write('WKU Restart Simulation', align="center",font=("Courier", 16, "bold"))
    turtle.goto(0,100)
    turtle.write('You can click on the button to view different view', align="center",font=("Courier", 12))
    turtle.goto(0,-100)

escape()

# %%
import turtle
          #上0 下1 左2 右3
dic ={"gate": ["","","gatel","gater"],
    "gater": ["","gate","",""],
    "gatel": ["","gate","ab",""],
    "ab": ["ab1","gatel","",""],
    "ab1": ["ab2","ab","","b"],
    "ab2": ["","ab1","","ab3"],
    "ab3": ["","ab2","",""],
    "b": ["c","ab1","bc1",""],
    "bc1": ["","b","",""],
    "c": ["","b","cdl","cdr"],
    "cdr": ["cdr1","c","",""],
    "cdl": ["","c","",""],
    "cdr1": ["bridge","cdr","",""],
    "bridge": ["","cdr1","","cbpm"],
    "cbpm": ["cbpm1","bridge","",""],
    "cbpm1": ["cbpm2","cbpm","",""],
    "cbpm2": ["subway","cbpm1","",""],
    "subway": ["cbpm3","cbpm2","",""],
    "cbpm3": ["qiuguanl","subway","",""],
    "qiuguanl": ["dom","cbpm3","qiuguangate",""],
    "qiuguangate": ["","qiuguanl","",""],
    "dom": ["dom2","qiuguanl","doml","domr"],
    "dom1": ["","dom","",""],
    "zhuxuan": ["","","",""],
    "domr": ["","dom","",""],
    "doml": ["","dom","",""],
    "dom2": ["","dom","","dom2r"],
    "dom2r": ["tenfeet","tenfeet","",""],
    "tenfeet": ["","dom2r","",""]
      }

windows = turtle.Screen()
windows.title("campus overview")
windows.setup(1200, 1000)
last = ".png"
name = "gate"
# pic = dic[name][0]
turtle.bgpic(name+last)


# turtle.clear()
# turtle.penup()
# turtle.speed(10)#0-10
# turtle.color('red')

# turtle.goto(200,100)
# na = turtle.textinput('Input', 'Enter your name')
# turtle.write(na)

def up():
    global name
    pic = dic[name][0]
    if pic != "":
        name = pic
        turtle.bgpic(pic+last)
def left():
    global name
    pic = dic[name][2]
    if pic != "":
        name = pic
        turtle.bgpic(pic+last)
def right():
    global name
    pic = dic[name][3]
    if pic != "":
        name = pic
        turtle.bgpic(pic+last)
def down():
    global name
    pic = dic[name][1]
    if pic != "":
        name = pic
        turtle.bgpic(pic+last)

while True:
    turtle.onkey(up, "Up")
    turtle.onkey(down,"Down")
    turtle.onkey(left, "Left")
    turtle.onkey(right, "Right")
    # window await
    turtle.listen()
    windows.mainloop()
#     break

turtle.goto(200,100)
name = turtle.textinput('Input', 'Enter your name')
turtle.write(name)
